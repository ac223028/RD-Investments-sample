# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("...", index_col='cross')

# %%
df.columns
# Out:
# Index(['volume times direction', 'number of positives', 'number of negatives',
#        'number of zeros', 'magnitude of the wins', 'magnitude of the losses',
#        'total price is you were to buy it all'],
#       dtype='object')

# %%
df['weights'] = df['number of positives'] / ( df['number of positives'] + df['number of negatives'])

# %%
df = df.dropna()

# %%
df
# Out:
#                                                     volume times direction  \
# cross
# ('CDL2CROWS', 0.0)X('CDL2CROWS', 0.0)                         6.530235e+11
# ('CDL2CROWS', 0.0)X('CDL3BLACKCROWS', 0.0)                    6.529965e+11
# ('CDL2CROWS', 0.0)X('CDL3BLACKCROWS', -100.0)                 2.698473e+07
# ('CDL2CROWS', 0.0)X('CDL3INSIDE', 0.0)                        6.514185e+11
# ('CDL2CROWS', 0.0)X('CDL3INSIDE', 100.0)                      3.518403e+07
# ('CDL2CROWS', 0.0)X('CDL3INSIDE', -100.0)                     1.569833e+09
# ('CDL2CROWS', 0.0)X('CDL3LINESTRIKE', 0.0)                    6.530959e+11
# ('CDL2CROWS', 0.0)X('CDL3LINESTRIKE', -100.0)                -1.717576e+07
# ('CDL2CROWS', 0.0)X('CDL3LINESTRIKE', 100.0)                 -5.519735e+07
# ('CDL2CROWS', 0.0)X('CDL3OUTSIDE', 0.0)                       6.490321e+11
# ('CDL2CROWS', 0.0)X('CDL3OUTSIDE', 100.0)                    -3.838269e+09
# ...

# %%
plt.hist(df['weights'], range=[0.45, 0.65])
# Out:
# (array([ 124.,  395., 1216., 3235., 1267.,  873.,  425.,  315.,  112.,
#           46.]),
#  array([0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['weights'], df['total price is you were to buy it all'])

# %%
odf = df[df['weights']<0.30]

# %%
odf
# Out:
#                                                     volume times direction  \
# cross
# ('CDL2CROWS', 0.0)X('CDLKICKING', 100.0)                         4924210.0
# ('CDL2CROWS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)              -31239898.0
# ('CDL2CROWS', -100.0)X('CDLGRAVESTONEDOJI', 100.0)               -823164.0
# ('CDL2CROWS', -100.0)X('CDLTAKURI', 100.0)                      -1109880.0
# ('CDL2CROWS', -100.0)X('CDLTRISTAR', -100.0)                    -1524180.0
# ('CDL3BLACKCROWS', 0.0)X('CDLKICKING', 100.0)                    4924210.0
# ('CDL3BLACKCROWS', 0.0)X('CDLKICKINGBYLENGTH', ...             -31239898.0
# ('CDL3INSIDE', 0.0)X('CDLKICKING', 100.0)                        4924210.0
# ('CDL3INSIDE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)             -31239898.0
# ('CDL3INSIDE', 100.0)X('CDLHIKKAKEMOD', 100.0)                   -613566.0
# ('CDL3INSIDE', -100.0)X('CDLDRAGONFLYDOJI', 100.0)             -38544811.0
# ...

# %%
odf['holding'] = odf['volume times direction'] * odf['weights']
# Out:
# A:\Anaconda\envs\pylive\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
odf
# Out:
#                                                     volume times direction  \
# cross
# ('CDL2CROWS', 0.0)X('CDLKICKING', 100.0)                         4924210.0
# ('CDL2CROWS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)              -31239898.0
# ('CDL2CROWS', -100.0)X('CDLGRAVESTONEDOJI', 100.0)               -823164.0
# ('CDL2CROWS', -100.0)X('CDLTAKURI', 100.0)                      -1109880.0
# ('CDL2CROWS', -100.0)X('CDLTRISTAR', -100.0)                    -1524180.0
# ('CDL3BLACKCROWS', 0.0)X('CDLKICKING', 100.0)                    4924210.0
# ('CDL3BLACKCROWS', 0.0)X('CDLKICKINGBYLENGTH', ...             -31239898.0
# ('CDL3INSIDE', 0.0)X('CDLKICKING', 100.0)                        4924210.0
# ('CDL3INSIDE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)             -31239898.0
# ('CDL3INSIDE', 100.0)X('CDLHIKKAKEMOD', 100.0)                   -613566.0
# ('CDL3INSIDE', -100.0)X('CDLDRAGONFLYDOJI', 100.0)             -38544811.0
# ...

# %%
odf['holding'].sum() / odf['volume times direction'].sum()
# Out:
# 0.15160636314612122

# %%
odf['volume times direction'].mean()
# Out:
# -14026106.212851405

# %%
odf['count'] = odf['number of positives'] + odf['number of negatives'] + odf['number of zeros']
# Out:
# A:\Anaconda\envs\pylive\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
odf['count'].sum() / 1500
# Out:
# 85.76266666666666

# %%
odf['magnitude of the losses'].sum() / odf.size
# Out:
# -0.5478000000000002

# %%
odf['total price is you were to buy it all'].sum()
# Out:
# -1042.0480000000011

# %%
odf['magnitude of the losses'].sum()
# Out:
# -1364.0220000000004

# %%
odf['magnitude of the losses'].sum() / odf['total price is you were to buy it all'].sum()
# Out:
# 1.3089819278958348

# %%
odf['number of negatives'].sum() / odf['number of positives'].sum()
# Out:
# 4.701030927835052

# %%
for i in odf.index:
    print(i+f"%{float(odf.loc[i, ['weights']])}")
# Out:
# ('CDL2CROWS', 0.0)X('CDLKICKING', 100.0)%0.2
# ('CDL2CROWS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
# ('CDL2CROWS', -100.0)X('CDLGRAVESTONEDOJI', 100.0)%0.0
# ('CDL2CROWS', -100.0)X('CDLTAKURI', 100.0)%0.0
# ('CDL2CROWS', -100.0)X('CDLTRISTAR', -100.0)%0.25
# ('CDL3BLACKCROWS', 0.0)X('CDLKICKING', 100.0)%0.2
# ('CDL3BLACKCROWS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
# ('CDL3INSIDE', 0.0)X('CDLKICKING', 100.0)%0.2
# ('CDL3INSIDE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
# ('CDL3INSIDE', 100.0)X('CDLHIKKAKEMOD', 100.0)%0.0
# ('CDL3INSIDE', -100.0)X('CDLDRAGONFLYDOJI', 100.0)%0.2222222222222222
# ('CDL3INSIDE', -100.0)X('CDLHANGINGMAN', -100.0)%0.0
# ('CDL3INSIDE', -100.0)X('CDLHIKKAKEMOD', -200.0)%0.0
# ('CDL3INSIDE', -100.0)X('CDLMATCHINGLOW', 100.0)%0.23076923076923078
# ('CDL3INSIDE', -100.0)X('CDLTAKURI', 100.0)%0.2222222222222222
# ('CDL3LINESTRIKE', 0.0)X('CDLKICKING', 100.0)%0.2
# ...

# %%
x = '''
('CDL2CROWS', 0.0)X('CDLKICKING', 100.0)%0.2
('CDL2CROWS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDL2CROWS', -100.0)X('CDLGRAVESTONEDOJI', 100.0)%0.0
('CDL2CROWS', -100.0)X('CDLTAKURI', 100.0)%0.0
('CDL2CROWS', -100.0)X('CDLTRISTAR', -100.0)%0.25
('CDL3BLACKCROWS', 0.0)X('CDLKICKING', 100.0)%0.2
('CDL3BLACKCROWS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDL3INSIDE', 0.0)X('CDLKICKING', 100.0)%0.2
('CDL3INSIDE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDL3INSIDE', 100.0)X('CDLHIKKAKEMOD', 100.0)%0.0
('CDL3INSIDE', -100.0)X('CDLDRAGONFLYDOJI', 100.0)%0.2222222222222222
('CDL3INSIDE', -100.0)X('CDLHANGINGMAN', -100.0)%0.0
('CDL3INSIDE', -100.0)X('CDLHIKKAKEMOD', -200.0)%0.0
('CDL3INSIDE', -100.0)X('CDLMATCHINGLOW', 100.0)%0.23076923076923078
('CDL3INSIDE', -100.0)X('CDLTAKURI', 100.0)%0.2222222222222222
('CDL3LINESTRIKE', 0.0)X('CDLKICKING', 100.0)%0.2
('CDL3LINESTRIKE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDL3LINESTRIKE', -100.0)X('CDLDOJI', 100.0)%0.0
('CDL3LINESTRIKE', -100.0)X('CDLDRAGONFLYDOJI', 100.0)%0.0
('CDL3LINESTRIKE', -100.0)X('CDLLONGLEGGEDDOJI', 100.0)%0.0
('CDL3LINESTRIKE', -100.0)X('CDLSHORTLINE', 100.0)%0.0
('CDL3LINESTRIKE', -100.0)X('CDLTAKURI', 100.0)%0.0
('CDL3LINESTRIKE', 100.0)X('CDLDARKCLOUDCOVER', -100.0)%0.0
('CDL3LINESTRIKE', 100.0)X('CDLDRAGONFLYDOJI', 100.0)%0.0
('CDL3LINESTRIKE', 100.0)X('CDLHAMMER', 100.0)%0.0
('CDL3LINESTRIKE', 100.0)X('CDLHANGINGMAN', -100.0)%0.0
('CDL3LINESTRIKE', 100.0)X('CDLHIKKAKE', 100.0)%0.23076923076923078
('CDL3LINESTRIKE', 100.0)X('CDLHIKKAKEMOD', -200.0)%0.0
('CDL3LINESTRIKE', 100.0)X('CDLLONGLEGGEDDOJI', 100.0)%0.0
('CDL3LINESTRIKE', 100.0)X('CDLTAKURI', 100.0)%0.0
('CDL3OUTSIDE', 0.0)X('CDLKICKING', 100.0)%0.2
('CDL3OUTSIDE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDL3OUTSIDE', 100.0)X('CDLBELTHOLD', -100.0)%0.29850746268656714
('CDL3OUTSIDE', 100.0)X('CDLHIKKAKEMOD', -100.0)%0.0
('CDL3OUTSIDE', 100.0)X('CDLMARUBOZU', -100.0)%0.2857142857142857
('CDL3STARSINSOUTH', 0.0)X('CDLKICKING', 100.0)%0.2
('CDL3STARSINSOUTH', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDL3WHITESOLDIERS', 0.0)X('CDLKICKING', 100.0)%0.2
('CDL3WHITESOLDIERS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLABANDONEDBABY', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLABANDONEDBABY', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.2
('CDLABANDONEDBABY', -100.0)X('CDLDOJI', 100.0)%0.0
('CDLABANDONEDBABY', -100.0)X('CDLEVENINGSTAR', 0.0)%0.0
('CDLABANDONEDBABY', -100.0)X('CDLKICKING', -100.0)%0.0
('CDLABANDONEDBABY', -100.0)X('CDLKICKINGBYLENGTH', -100.0)%0.0
('CDLABANDONEDBABY', -100.0)X('CDLTRISTAR', -100.0)%0.0
('CDLADVANCEBLOCK', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLADVANCEBLOCK', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLBELTHOLD', -100.0)X('CDLKICKINGBYLENGTH', -100.0)%0.2
('CDLBELTHOLD', 100.0)X('CDLDOJISTAR', 100.0)%0.0
('CDLBELTHOLD', 100.0)X('CDLHIKKAKE', -200.0)%0.29411764705882354
('CDLBELTHOLD', 100.0)X('CDLHIKKAKEMOD', -200.0)%0.0
('CDLBELTHOLD', 100.0)X('CDLKICKING', 100.0)%0.2
('CDLBELTHOLD', 100.0)X('CDLKICKINGBYLENGTH', 100.0)%0.25
('CDLBELTHOLD', 100.0)X('CDLKICKINGBYLENGTH', -100.0)%0.0
('CDLBREAKAWAY', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLBREAKAWAY', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.2
('CDLBREAKAWAY', -100.0)X('CDLDOJI', 100.0)%0.25
('CDLBREAKAWAY', -100.0)X('CDLEVENINGSTAR', -100.0)%0.0
('CDLBREAKAWAY', -100.0)X('CDLGRAVESTONEDOJI', 100.0)%0.0
('CDLBREAKAWAY', -100.0)X('CDLHIGHWAVE', -100.0)%0.2
('CDLBREAKAWAY', -100.0)X('CDLHIKKAKE', -200.0)%0.0
('CDLBREAKAWAY', -100.0)X('CDLKICKING', -100.0)%0.0
('CDLBREAKAWAY', -100.0)X('CDLKICKINGBYLENGTH', -100.0)%0.0
('CDLBREAKAWAY', -100.0)X('CDLLONGLEGGEDDOJI', 100.0)%0.25
('CDLBREAKAWAY', -100.0)X('CDLSHORTLINE', -100.0)%0.0
('CDLBREAKAWAY', -100.0)X('CDLSPINNINGTOP', -100.0)%0.16666666666666666
('CDLBREAKAWAY', 100.0)X('CDLDOJI', 100.0)%0.0
('CDLBREAKAWAY', 100.0)X('CDLENGULFING', 100.0)%0.2857142857142857
('CDLBREAKAWAY', 100.0)X('CDLHIGHWAVE', 100.0)%0.0
('CDLBREAKAWAY', 100.0)X('CDLLONGLEGGEDDOJI', 100.0)%0.0
('CDLBREAKAWAY', 100.0)X('CDLRICKSHAWMAN', 100.0)%0.0
('CDLBREAKAWAY', 100.0)X('CDLSPINNINGTOP', 100.0)%0.0
('CDLBREAKAWAY', 100.0)X('CDLUNIQUE3RIVER', 100.0)%0.0
('CDLCLOSINGMARUBOZU', -100.0)X('CDLDOJISTAR', -100.0)%0.2857142857142857
('CDLCLOSINGMARUBOZU', -100.0)X('CDLKICKINGBYLENGTH', -100.0)%0.2
('CDLCLOSINGMARUBOZU', -100.0)X('CDLTAKURI', 100.0)%0.0
('CDLCLOSINGMARUBOZU', 100.0)X('CDLKICKING', 100.0)%0.2
('CDLCLOSINGMARUBOZU', 100.0)X('CDLKICKINGBYLENGTH', 100.0)%0.25
('CDLCLOSINGMARUBOZU', 100.0)X('CDLKICKINGBYLENGTH', -100.0)%0.0
('CDLCONCEALBABYSWALL', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLCONCEALBABYSWALL', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLCOUNTERATTACK', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLCOUNTERATTACK', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLCOUNTERATTACK', -100.0)X('CDLTRISTAR', -100.0)%0.16666666666666666
('CDLCOUNTERATTACK', 100.0)X('CDLMORNINGDOJISTAR', 100.0)%0.0
('CDLCOUNTERATTACK', 100.0)X('CDLXSIDEGAP3METHODS', -100.0)%0.0
('CDLDARKCLOUDCOVER', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLDARKCLOUDCOVER', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLDARKCLOUDCOVER', -100.0)X('CDLHIKKAKE', -200.0)%0.0
('CDLDARKCLOUDCOVER', -100.0)X('CDLSPINNINGTOP', -100.0)%0.0
('CDLDOJI', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.25
('CDLDOJI', 100.0)X('CDLKICKING', 100.0)%0.0
('CDLDOJI', 100.0)X('CDLKICKING', -100.0)%0.0
('CDLDOJI', 100.0)X('CDLKICKINGBYLENGTH', 100.0)%0.0
('CDLDOJI', 100.0)X('CDLKICKINGBYLENGTH', -100.0)%0.0
('CDLDOJISTAR', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLDOJISTAR', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLDOJISTAR', 100.0)X('CDLHIKKAKE', -100.0)%0.0
('CDLDOJISTAR', -100.0)X('CDLGAPSIDESIDEWHITE', 100.0)%0.17647058823529413
('CDLDRAGONFLYDOJI', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLDRAGONFLYDOJI', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLDRAGONFLYDOJI', 100.0)X('CDLHIKKAKEMOD', 200.0)%0.0
('CDLDRAGONFLYDOJI', 100.0)X('CDLLADDERBOTTOM', 100.0)%0.125
('CDLDRAGONFLYDOJI', 100.0)X('CDLTHRUSTING', -100.0)%0.25
('CDLENGULFING', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLENGULFING', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLENGULFING', 100.0)X('CDLONNECK', -100.0)%0.0
('CDLEVENINGDOJISTAR', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLEVENINGDOJISTAR', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.25
('CDLEVENINGDOJISTAR', -100.0)X('CDLKICKING', -100.0)%0.0
('CDLEVENINGDOJISTAR', -100.0)X('CDLKICKINGBYLENGTH', -100.0)%0.0
('CDLEVENINGSTAR', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLEVENINGSTAR', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLGAPSIDESIDEWHITE', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLGAPSIDESIDEWHITE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLGAPSIDESIDEWHITE', -100.0)X('CDLHIKKAKEMOD', -100.0)%0.0
('CDLGRAVESTONEDOJI', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLGRAVESTONEDOJI', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLGRAVESTONEDOJI', 100.0)X('CDLHIKKAKEMOD', -100.0)%0.16666666666666666
('CDLGRAVESTONEDOJI', 100.0)X('CDLTASUKIGAP', 100.0)%0.1
('CDLHAMMER', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLHAMMER', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLHAMMER', 100.0)X('CDLHIKKAKEMOD', 200.0)%0.0
('CDLHANGINGMAN', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLHANGINGMAN', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLHANGINGMAN', -100.0)X('CDLMATHOLD', 100.0)%0.0
('CDLHANGINGMAN', -100.0)X('CDLUPSIDEGAP2CROWS', -100.0)%0.0
('CDLHARAMI', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLHARAMI', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLHARAMI', 100.0)X('CDLHIKKAKEMOD', 100.0)%0.0
('CDLHARAMI', -100.0)X('CDLHIKKAKEMOD', -100.0)%0.0
('CDLHARAMICROSS', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLHARAMICROSS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLHARAMICROSS', 100.0)X('CDLHIKKAKEMOD', 100.0)%0.0
('CDLHARAMICROSS', 100.0)X('CDLHIKKAKEMOD', -100.0)%0.0
('CDLHARAMICROSS', -100.0)X('CDLHIKKAKEMOD', 100.0)%0.0
('CDLHARAMICROSS', -100.0)X('CDLHIKKAKEMOD', -100.0)%0.0
('CDLHIGHWAVE', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLHIGHWAVE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLHIGHWAVE', -100.0)X('CDLHIKKAKEMOD', 200.0)%0.0
('CDLHIKKAKE', 0.0)X('CDLHIKKAKEMOD', 200.0)%0.0
('CDLHIKKAKE', 0.0)X('CDLKICKING', 100.0)%0.0
('CDLHIKKAKE', 0.0)X('CDLKICKING', -100.0)%0.2
('CDLHIKKAKE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.0
('CDLHIKKAKE', 100.0)X('CDLSEPARATINGLINES', 100.0)%0.09090909090909091
('CDLHIKKAKE', 200.0)X('CDLMARUBOZU', -100.0)%0.0
('CDLHIKKAKE', 200.0)X('CDLXSIDEGAP3METHODS', -100.0)%0.0
('CDLHIKKAKE', -100.0)X('CDLHIKKAKEMOD', -200.0)%0.0
('CDLHIKKAKE', -100.0)X('CDLXSIDEGAP3METHODS', 100.0)%0.2857142857142857
('CDLHIKKAKEMOD', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLHIKKAKEMOD', 0.0)X('CDLKICKING', -100.0)%0.2
('CDLHIKKAKEMOD', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.0
('CDLHIKKAKEMOD', 200.0)X('CDLLADDERBOTTOM', 100.0)%0.0
('CDLHIKKAKEMOD', 200.0)X('CDLSEPARATINGLINES', 100.0)%0.0
('CDLHIKKAKEMOD', 200.0)X('CDLSHOOTINGSTAR', -100.0)%0.0
('CDLHIKKAKEMOD', 200.0)X('CDLSPINNINGTOP', -100.0)%0.0
('CDLHIKKAKEMOD', 200.0)X('CDLTAKURI', 100.0)%0.0
('CDLHIKKAKEMOD', 200.0)X('CDLTRISTAR', 100.0)%0.0
('CDLHIKKAKEMOD', -200.0)X('CDLMATCHINGLOW', 100.0)%0.0
('CDLHIKKAKEMOD', -100.0)X('CDLHOMINGPIGEON', 100.0)%0.0
('CDLHIKKAKEMOD', -100.0)X('CDLTASUKIGAP', -100.0)%0.0
('CDLHIKKAKEMOD', -100.0)X('CDLTRISTAR', 100.0)%0.0
('CDLHOMINGPIGEON', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLHOMINGPIGEON', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLIDENTICAL3CROWS', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLIDENTICAL3CROWS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLINNECK', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLINNECK', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLINVERTEDHAMMER', 0.0)X('CDLKICKING', 100.0)%0.2
('CDLINVERTEDHAMMER', 0.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLKICKING', 100.0)X('CDLKICKING', 100.0)%0.2
('CDLKICKING', 100.0)X('CDLKICKINGBYLENGTH', 100.0)%0.25
('CDLKICKING', 100.0)X('CDLKICKINGBYLENGTH', -100.0)%0.0
('CDLKICKING', 100.0)X('CDLLADDERBOTTOM', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLLONGLEGGEDDOJI', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLLONGLINE', 100.0)%0.2
('CDLKICKING', 100.0)X('CDLMARUBOZU', 100.0)%0.2
('CDLKICKING', 100.0)X('CDLMATCHINGLOW', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLMATHOLD', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLMORNINGDOJISTAR', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLMORNINGSTAR', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLONNECK', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLPIERCING', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLRICKSHAWMAN', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLRISEFALL3METHODS', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLSEPARATINGLINES', 0.0)%0.25
('CDLKICKING', 100.0)X('CDLSEPARATINGLINES', 100.0)%0.0
('CDLKICKING', 100.0)X('CDLSHOOTINGSTAR', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLSHORTLINE', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLSPINNINGTOP', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLSTALLEDPATTERN', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLSTICKSANDWICH', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLTAKURI', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLTASUKIGAP', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLTHRUSTING', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLTRISTAR', 0.0)%0.25
('CDLKICKING', 100.0)X('CDLTRISTAR', 100.0)%0.0
('CDLKICKING', 100.0)X('CDLUNIQUE3RIVER', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLUPSIDEGAP2CROWS', 0.0)%0.2
('CDLKICKING', 100.0)X('CDLXSIDEGAP3METHODS', 0.0)%0.2
('CDLKICKING', -100.0)X('CDLKICKINGBYLENGTH', -100.0)%0.2
('CDLKICKING', -100.0)X('CDLSEPARATINGLINES', 0.0)%0.2
('CDLKICKING', -100.0)X('CDLTRISTAR', -100.0)%0.0
('CDLKICKINGBYLENGTH', 100.0)X('CDLLONGLINE', 100.0)%0.25
('CDLKICKINGBYLENGTH', 100.0)X('CDLMARUBOZU', 100.0)%0.25
('CDLKICKINGBYLENGTH', 100.0)X('CDLTRISTAR', 100.0)%0.0
('CDLKICKINGBYLENGTH', -100.0)X('CDLKICKINGBYLENGTH', -100.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLLADDERBOTTOM', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLLONGLEGGEDDOJI', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLLONGLINE', -100.0)%0.2
('CDLKICKINGBYLENGTH', -100.0)X('CDLLONGLINE', 100.0)%0.0
('CDLKICKINGBYLENGTH', -100.0)X('CDLMARUBOZU', -100.0)%0.2
('CDLKICKINGBYLENGTH', -100.0)X('CDLMARUBOZU', 100.0)%0.0
('CDLKICKINGBYLENGTH', -100.0)X('CDLMATCHINGLOW', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLMATHOLD', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLMORNINGDOJISTAR', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLMORNINGSTAR', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLONNECK', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLPIERCING', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLRICKSHAWMAN', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLRISEFALL3METHODS', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLSEPARATINGLINES', 0.0)%0.0
('CDLKICKINGBYLENGTH', -100.0)X('CDLSEPARATINGLINES', 100.0)%0.0
('CDLKICKINGBYLENGTH', -100.0)X('CDLSHOOTINGSTAR', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLSHORTLINE', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLSPINNINGTOP', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLSTALLEDPATTERN', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLSTICKSANDWICH', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLTAKURI', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLTASUKIGAP', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLTHRUSTING', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLTRISTAR', 0.0)%0.2
('CDLKICKINGBYLENGTH', -100.0)X('CDLTRISTAR', -100.0)%0.0
('CDLKICKINGBYLENGTH', -100.0)X('CDLUNIQUE3RIVER', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLUPSIDEGAP2CROWS', 0.0)%0.16666666666666666
('CDLKICKINGBYLENGTH', -100.0)X('CDLXSIDEGAP3METHODS', 0.0)%0.16666666666666666
('CDLLADDERBOTTOM', 100.0)X('CDLTAKURI', 100.0)%0.125
('CDLLONGLEGGEDDOJI', 100.0)X('CDLPIERCING', 100.0)%0.0
('CDLMARUBOZU', -100.0)X('CDLTAKURI', 100.0)%0.0
('CDLMATHOLD', 100.0)X('CDLRISEFALL3METHODS', 100.0)%0.0
('CDLRICKSHAWMAN', 100.0)X('CDLSEPARATINGLINES', 100.0)%0.0
('CDLRISEFALL3METHODS', 100.0)X('CDLSEPARATINGLINES', 100.0)%0.2
('CDLSEPARATINGLINES', 100.0)X('CDLTRISTAR', -100.0)%0.0
('CDLSEPARATINGLINES', -100.0)X('CDLSTICKSANDWICH', 100.0)%0.25
('CDLSEPARATINGLINES', -100.0)X('CDLTRISTAR', 100.0)%0.0
('CDLSHOOTINGSTAR', -100.0)X('CDLSTICKSANDWICH', 100.0)%0.0
('CDLTAKURI', 100.0)X('CDLTHRUSTING', -100.0)%0.25
('CDLTHRUSTING', -100.0)X('CDLTRISTAR', -100.0)%0.0
'''

# %%
x = '''
('CDL2CROWS', 0.0)X('CDLKICKING', 100.0)
('CDL2CROWS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDL2CROWS', -100.0)X('CDLGRAVESTONEDOJI', 100.0)
('CDL2CROWS', -100.0)X('CDLTAKURI', 100.0)
('CDL2CROWS', -100.0)X('CDLTRISTAR', -100.0)
('CDL3BLACKCROWS', 0.0)X('CDLKICKING', 100.0)
('CDL3BLACKCROWS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDL3INSIDE', 0.0)X('CDLKICKING', 100.0)
('CDL3INSIDE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDL3INSIDE', 100.0)X('CDLHIKKAKEMOD', 100.0)
('CDL3INSIDE', -100.0)X('CDLDRAGONFLYDOJI', 100.0)
('CDL3INSIDE', -100.0)X('CDLHANGINGMAN', -100.0)
('CDL3INSIDE', -100.0)X('CDLHIKKAKEMOD', -200.0)
('CDL3INSIDE', -100.0)X('CDLMATCHINGLOW', 100.0)
('CDL3INSIDE', -100.0)X('CDLTAKURI', 100.0)
('CDL3LINESTRIKE', 0.0)X('CDLKICKING', 100.0)
('CDL3LINESTRIKE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDL3LINESTRIKE', -100.0)X('CDLDOJI', 100.0)
('CDL3LINESTRIKE', -100.0)X('CDLDRAGONFLYDOJI', 100.0)
('CDL3LINESTRIKE', -100.0)X('CDLLONGLEGGEDDOJI', 100.0)
('CDL3LINESTRIKE', -100.0)X('CDLSHORTLINE', 100.0)
('CDL3LINESTRIKE', -100.0)X('CDLTAKURI', 100.0)
('CDL3LINESTRIKE', 100.0)X('CDLDARKCLOUDCOVER', -100.0)
('CDL3LINESTRIKE', 100.0)X('CDLDRAGONFLYDOJI', 100.0)
('CDL3LINESTRIKE', 100.0)X('CDLHAMMER', 100.0)
('CDL3LINESTRIKE', 100.0)X('CDLHANGINGMAN', -100.0)
('CDL3LINESTRIKE', 100.0)X('CDLHIKKAKE', 100.0)
('CDL3LINESTRIKE', 100.0)X('CDLHIKKAKEMOD', -200.0)
('CDL3LINESTRIKE', 100.0)X('CDLLONGLEGGEDDOJI', 100.0)
('CDL3LINESTRIKE', 100.0)X('CDLTAKURI', 100.0)
('CDL3OUTSIDE', 0.0)X('CDLKICKING', 100.0)
('CDL3OUTSIDE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDL3OUTSIDE', 100.0)X('CDLBELTHOLD', -100.0)
('CDL3OUTSIDE', 100.0)X('CDLHIKKAKEMOD', -100.0)
('CDL3OUTSIDE', 100.0)X('CDLMARUBOZU', -100.0)
('CDL3STARSINSOUTH', 0.0)X('CDLKICKING', 100.0)
('CDL3STARSINSOUTH', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDL3WHITESOLDIERS', 0.0)X('CDLKICKING', 100.0)
('CDL3WHITESOLDIERS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLABANDONEDBABY', 0.0)X('CDLKICKING', 100.0)
('CDLABANDONEDBABY', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLABANDONEDBABY', -100.0)X('CDLDOJI', 100.0)
('CDLABANDONEDBABY', -100.0)X('CDLEVENINGSTAR', 0.0)
('CDLABANDONEDBABY', -100.0)X('CDLKICKING', -100.0)
('CDLABANDONEDBABY', -100.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLABANDONEDBABY', -100.0)X('CDLTRISTAR', -100.0)
('CDLADVANCEBLOCK', 0.0)X('CDLKICKING', 100.0)
('CDLADVANCEBLOCK', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLBELTHOLD', -100.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLBELTHOLD', 100.0)X('CDLDOJISTAR', 100.0)
('CDLBELTHOLD', 100.0)X('CDLHIKKAKE', -200.0)
('CDLBELTHOLD', 100.0)X('CDLHIKKAKEMOD', -200.0)
('CDLBELTHOLD', 100.0)X('CDLKICKING', 100.0)
('CDLBELTHOLD', 100.0)X('CDLKICKINGBYLENGTH', 100.0)
('CDLBELTHOLD', 100.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLBREAKAWAY', 0.0)X('CDLKICKING', 100.0)
('CDLBREAKAWAY', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLBREAKAWAY', -100.0)X('CDLDOJI', 100.0)
('CDLBREAKAWAY', -100.0)X('CDLEVENINGSTAR', -100.0)
('CDLBREAKAWAY', -100.0)X('CDLGRAVESTONEDOJI', 100.0)
('CDLBREAKAWAY', -100.0)X('CDLHIGHWAVE', -100.0)
('CDLBREAKAWAY', -100.0)X('CDLHIKKAKE', -200.0)
('CDLBREAKAWAY', -100.0)X('CDLKICKING', -100.0)
('CDLBREAKAWAY', -100.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLBREAKAWAY', -100.0)X('CDLLONGLEGGEDDOJI', 100.0)
('CDLBREAKAWAY', -100.0)X('CDLSHORTLINE', -100.0)
('CDLBREAKAWAY', -100.0)X('CDLSPINNINGTOP', -100.0)
('CDLBREAKAWAY', 100.0)X('CDLDOJI', 100.0)
('CDLBREAKAWAY', 100.0)X('CDLENGULFING', 100.0)
('CDLBREAKAWAY', 100.0)X('CDLHIGHWAVE', 100.0)
('CDLBREAKAWAY', 100.0)X('CDLLONGLEGGEDDOJI', 100.0)
('CDLBREAKAWAY', 100.0)X('CDLRICKSHAWMAN', 100.0)
('CDLBREAKAWAY', 100.0)X('CDLSPINNINGTOP', 100.0)
('CDLBREAKAWAY', 100.0)X('CDLUNIQUE3RIVER', 100.0)
('CDLCLOSINGMARUBOZU', -100.0)X('CDLDOJISTAR', -100.0)
('CDLCLOSINGMARUBOZU', -100.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLCLOSINGMARUBOZU', -100.0)X('CDLTAKURI', 100.0)
('CDLCLOSINGMARUBOZU', 100.0)X('CDLKICKING', 100.0)
('CDLCLOSINGMARUBOZU', 100.0)X('CDLKICKINGBYLENGTH', 100.0)
('CDLCLOSINGMARUBOZU', 100.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLCONCEALBABYSWALL', 0.0)X('CDLKICKING', 100.0)
('CDLCONCEALBABYSWALL', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLCOUNTERATTACK', 0.0)X('CDLKICKING', 100.0)
('CDLCOUNTERATTACK', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLCOUNTERATTACK', -100.0)X('CDLTRISTAR', -100.0)
('CDLCOUNTERATTACK', 100.0)X('CDLMORNINGDOJISTAR', 100.0)
('CDLCOUNTERATTACK', 100.0)X('CDLXSIDEGAP3METHODS', -100.0)
('CDLDARKCLOUDCOVER', 0.0)X('CDLKICKING', 100.0)
('CDLDARKCLOUDCOVER', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLDARKCLOUDCOVER', -100.0)X('CDLHIKKAKE', -200.0)
('CDLDARKCLOUDCOVER', -100.0)X('CDLSPINNINGTOP', -100.0)
('CDLDOJI', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLDOJI', 100.0)X('CDLKICKING', 100.0)
('CDLDOJI', 100.0)X('CDLKICKING', -100.0)
('CDLDOJI', 100.0)X('CDLKICKINGBYLENGTH', 100.0)
('CDLDOJI', 100.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLDOJISTAR', 0.0)X('CDLKICKING', 100.0)
('CDLDOJISTAR', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLDOJISTAR', 100.0)X('CDLHIKKAKE', -100.0)
('CDLDOJISTAR', -100.0)X('CDLGAPSIDESIDEWHITE', 100.0)
('CDLDRAGONFLYDOJI', 0.0)X('CDLKICKING', 100.0)
('CDLDRAGONFLYDOJI', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLDRAGONFLYDOJI', 100.0)X('CDLHIKKAKEMOD', 200.0)
('CDLDRAGONFLYDOJI', 100.0)X('CDLLADDERBOTTOM', 100.0)
('CDLDRAGONFLYDOJI', 100.0)X('CDLTHRUSTING', -100.0)
('CDLENGULFING', 0.0)X('CDLKICKING', 100.0)
('CDLENGULFING', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLENGULFING', 100.0)X('CDLONNECK', -100.0)
('CDLEVENINGDOJISTAR', 0.0)X('CDLKICKING', 100.0)
('CDLEVENINGDOJISTAR', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLEVENINGDOJISTAR', -100.0)X('CDLKICKING', -100.0)
('CDLEVENINGDOJISTAR', -100.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLEVENINGSTAR', 0.0)X('CDLKICKING', 100.0)
('CDLEVENINGSTAR', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLGAPSIDESIDEWHITE', 0.0)X('CDLKICKING', 100.0)
('CDLGAPSIDESIDEWHITE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLGAPSIDESIDEWHITE', -100.0)X('CDLHIKKAKEMOD', -100.0)
('CDLGRAVESTONEDOJI', 0.0)X('CDLKICKING', 100.0)
('CDLGRAVESTONEDOJI', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLGRAVESTONEDOJI', 100.0)X('CDLHIKKAKEMOD', -100.0)
('CDLGRAVESTONEDOJI', 100.0)X('CDLTASUKIGAP', 100.0)
('CDLHAMMER', 0.0)X('CDLKICKING', 100.0)
('CDLHAMMER', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLHAMMER', 100.0)X('CDLHIKKAKEMOD', 200.0)
('CDLHANGINGMAN', 0.0)X('CDLKICKING', 100.0)
('CDLHANGINGMAN', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLHANGINGMAN', -100.0)X('CDLMATHOLD', 100.0)
('CDLHANGINGMAN', -100.0)X('CDLUPSIDEGAP2CROWS', -100.0)
('CDLHARAMI', 0.0)X('CDLKICKING', 100.0)
('CDLHARAMI', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLHARAMI', 100.0)X('CDLHIKKAKEMOD', 100.0)
('CDLHARAMI', -100.0)X('CDLHIKKAKEMOD', -100.0)
('CDLHARAMICROSS', 0.0)X('CDLKICKING', 100.0)
('CDLHARAMICROSS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLHARAMICROSS', 100.0)X('CDLHIKKAKEMOD', 100.0)
('CDLHARAMICROSS', 100.0)X('CDLHIKKAKEMOD', -100.0)
('CDLHARAMICROSS', -100.0)X('CDLHIKKAKEMOD', 100.0)
('CDLHARAMICROSS', -100.0)X('CDLHIKKAKEMOD', -100.0)
('CDLHIGHWAVE', 0.0)X('CDLKICKING', 100.0)
('CDLHIGHWAVE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLHIGHWAVE', -100.0)X('CDLHIKKAKEMOD', 200.0)
('CDLHIKKAKE', 0.0)X('CDLHIKKAKEMOD', 200.0)
('CDLHIKKAKE', 0.0)X('CDLKICKING', 100.0)
('CDLHIKKAKE', 0.0)X('CDLKICKING', -100.0)
('CDLHIKKAKE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLHIKKAKE', 100.0)X('CDLSEPARATINGLINES', 100.0)
('CDLHIKKAKE', 200.0)X('CDLMARUBOZU', -100.0)
('CDLHIKKAKE', 200.0)X('CDLXSIDEGAP3METHODS', -100.0)
('CDLHIKKAKE', -100.0)X('CDLHIKKAKEMOD', -200.0)
('CDLHIKKAKE', -100.0)X('CDLXSIDEGAP3METHODS', 100.0)
('CDLHIKKAKEMOD', 0.0)X('CDLKICKING', 100.0)
('CDLHIKKAKEMOD', 0.0)X('CDLKICKING', -100.0)
('CDLHIKKAKEMOD', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLHIKKAKEMOD', 200.0)X('CDLLADDERBOTTOM', 100.0)
('CDLHIKKAKEMOD', 200.0)X('CDLSEPARATINGLINES', 100.0)
('CDLHIKKAKEMOD', 200.0)X('CDLSHOOTINGSTAR', -100.0)
('CDLHIKKAKEMOD', 200.0)X('CDLSPINNINGTOP', -100.0)
('CDLHIKKAKEMOD', 200.0)X('CDLTAKURI', 100.0)
('CDLHIKKAKEMOD', 200.0)X('CDLTRISTAR', 100.0)
('CDLHIKKAKEMOD', -200.0)X('CDLMATCHINGLOW', 100.0)
('CDLHIKKAKEMOD', -100.0)X('CDLHOMINGPIGEON', 100.0)
('CDLHIKKAKEMOD', -100.0)X('CDLTASUKIGAP', -100.0)
('CDLHIKKAKEMOD', -100.0)X('CDLTRISTAR', 100.0)
('CDLHOMINGPIGEON', 0.0)X('CDLKICKING', 100.0)
('CDLHOMINGPIGEON', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLIDENTICAL3CROWS', 0.0)X('CDLKICKING', 100.0)
('CDLIDENTICAL3CROWS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLINNECK', 0.0)X('CDLKICKING', 100.0)
('CDLINNECK', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLINVERTEDHAMMER', 0.0)X('CDLKICKING', 100.0)
('CDLINVERTEDHAMMER', 0.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLKICKING', 100.0)X('CDLKICKING', 100.0)
('CDLKICKING', 100.0)X('CDLKICKINGBYLENGTH', 100.0)
('CDLKICKING', 100.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLKICKING', 100.0)X('CDLLADDERBOTTOM', 0.0)
('CDLKICKING', 100.0)X('CDLLONGLEGGEDDOJI', 0.0)
('CDLKICKING', 100.0)X('CDLLONGLINE', 100.0)
('CDLKICKING', 100.0)X('CDLMARUBOZU', 100.0)
('CDLKICKING', 100.0)X('CDLMATCHINGLOW', 0.0)
('CDLKICKING', 100.0)X('CDLMATHOLD', 0.0)
('CDLKICKING', 100.0)X('CDLMORNINGDOJISTAR', 0.0)
('CDLKICKING', 100.0)X('CDLMORNINGSTAR', 0.0)
('CDLKICKING', 100.0)X('CDLONNECK', 0.0)
('CDLKICKING', 100.0)X('CDLPIERCING', 0.0)
('CDLKICKING', 100.0)X('CDLRICKSHAWMAN', 0.0)
('CDLKICKING', 100.0)X('CDLRISEFALL3METHODS', 0.0)
('CDLKICKING', 100.0)X('CDLSEPARATINGLINES', 0.0)
('CDLKICKING', 100.0)X('CDLSEPARATINGLINES', 100.0)
('CDLKICKING', 100.0)X('CDLSHOOTINGSTAR', 0.0)
('CDLKICKING', 100.0)X('CDLSHORTLINE', 0.0)
('CDLKICKING', 100.0)X('CDLSPINNINGTOP', 0.0)
('CDLKICKING', 100.0)X('CDLSTALLEDPATTERN', 0.0)
('CDLKICKING', 100.0)X('CDLSTICKSANDWICH', 0.0)
('CDLKICKING', 100.0)X('CDLTAKURI', 0.0)
('CDLKICKING', 100.0)X('CDLTASUKIGAP', 0.0)
('CDLKICKING', 100.0)X('CDLTHRUSTING', 0.0)
('CDLKICKING', 100.0)X('CDLTRISTAR', 0.0)
('CDLKICKING', 100.0)X('CDLTRISTAR', 100.0)
('CDLKICKING', 100.0)X('CDLUNIQUE3RIVER', 0.0)
('CDLKICKING', 100.0)X('CDLUPSIDEGAP2CROWS', 0.0)
('CDLKICKING', 100.0)X('CDLXSIDEGAP3METHODS', 0.0)
('CDLKICKING', -100.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLKICKING', -100.0)X('CDLSEPARATINGLINES', 0.0)
('CDLKICKING', -100.0)X('CDLTRISTAR', -100.0)
('CDLKICKINGBYLENGTH', 100.0)X('CDLLONGLINE', 100.0)
('CDLKICKINGBYLENGTH', 100.0)X('CDLMARUBOZU', 100.0)
('CDLKICKINGBYLENGTH', 100.0)X('CDLTRISTAR', 100.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLKICKINGBYLENGTH', -100.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLLADDERBOTTOM', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLLONGLEGGEDDOJI', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLLONGLINE', -100.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLLONGLINE', 100.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLMARUBOZU', -100.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLMARUBOZU', 100.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLMATCHINGLOW', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLMATHOLD', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLMORNINGDOJISTAR', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLMORNINGSTAR', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLONNECK', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLPIERCING', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLRICKSHAWMAN', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLRISEFALL3METHODS', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLSEPARATINGLINES', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLSEPARATINGLINES', 100.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLSHOOTINGSTAR', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLSHORTLINE', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLSPINNINGTOP', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLSTALLEDPATTERN', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLSTICKSANDWICH', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLTAKURI', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLTASUKIGAP', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLTHRUSTING', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLTRISTAR', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLTRISTAR', -100.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLUNIQUE3RIVER', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLUPSIDEGAP2CROWS', 0.0)
('CDLKICKINGBYLENGTH', -100.0)X('CDLXSIDEGAP3METHODS', 0.0)
('CDLLADDERBOTTOM', 100.0)X('CDLTAKURI', 100.0)
('CDLLONGLEGGEDDOJI', 100.0)X('CDLPIERCING', 100.0)
('CDLMARUBOZU', -100.0)X('CDLTAKURI', 100.0)
('CDLMATHOLD', 100.0)X('CDLRISEFALL3METHODS', 100.0)
('CDLRICKSHAWMAN', 100.0)X('CDLSEPARATINGLINES', 100.0)
('CDLRISEFALL3METHODS', 100.0)X('CDLSEPARATINGLINES', 100.0)
('CDLSEPARATINGLINES', 100.0)X('CDLTRISTAR', -100.0)
('CDLSEPARATINGLINES', -100.0)X('CDLSTICKSANDWICH', 100.0)
('CDLSEPARATINGLINES', -100.0)X('CDLTRISTAR', 100.0)
('CDLSHOOTINGSTAR', -100.0)X('CDLSTICKSANDWICH', 100.0)
('CDLTAKURI', 100.0)X('CDLTHRUSTING', -100.0)
('CDLTHRUSTING', -100.0)X('CDLTRISTAR', -100.0)
'''

# %%
y = x.strip().split('\n')

# %%
y
# Out:
# ["('CDL2CROWS', 0.0)X('CDLKICKING', 100.0)",
#  "('CDL2CROWS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)",
#  "('CDL2CROWS', -100.0)X('CDLGRAVESTONEDOJI', 100.0)",
#  "('CDL2CROWS', -100.0)X('CDLTAKURI', 100.0)",
#  "('CDL2CROWS', -100.0)X('CDLTRISTAR', -100.0)",
#  "('CDL3BLACKCROWS', 0.0)X('CDLKICKING', 100.0)",
#  "('CDL3BLACKCROWS', 0.0)X('CDLKICKINGBYLENGTH', -100.0)",
#  "('CDL3INSIDE', 0.0)X('CDLKICKING', 100.0)",
#  "('CDL3INSIDE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)",
#  "('CDL3INSIDE', 100.0)X('CDLHIKKAKEMOD', 100.0)",
#  "('CDL3INSIDE', -100.0)X('CDLDRAGONFLYDOJI', 100.0)",
#  "('CDL3INSIDE', -100.0)X('CDLHANGINGMAN', -100.0)",
#  "('CDL3INSIDE', -100.0)X('CDLHIKKAKEMOD', -200.0)",
#  "('CDL3INSIDE', -100.0)X('CDLMATCHINGLOW', 100.0)",
#  "('CDL3INSIDE', -100.0)X('CDLTAKURI', 100.0)",
#  "('CDL3LINESTRIKE', 0.0)X('CDLKICKING', 100.0)",
#  "('CDL3LINESTRIKE', 0.0)X('CDLKICKINGBYLENGTH', -100.0)",
#  "('CDL3LINESTRIKE', -100.0)X('CDLDOJI', 100.0)",
# ...

# %%
import re

z = [c.split("X", 1) for c in y]

# %%
z
# Out:
# [["('CDL2CROWS', 0.0)", "('CDLKICKING', 100.0)"],
#  ["('CDL2CROWS', 0.0)", "('CDLKICKINGBYLENGTH', -100.0)"],
#  ["('CDL2CROWS', -100.0)", "('CDLGRAVESTONEDOJI', 100.0)"],
#  ["('CDL2CROWS', -100.0)", "('CDLTAKURI', 100.0)"],
#  ["('CDL2CROWS', -100.0)", "('CDLTRISTAR', -100.0)"],
#  ["('CDL3BLACKCROWS', 0.0)", "('CDLKICKING', 100.0)"],
#  ["('CDL3BLACKCROWS', 0.0)", "('CDLKICKINGBYLENGTH', -100.0)"],
#  ["('CDL3INSIDE', 0.0)", "('CDLKICKING', 100.0)"],
#  ["('CDL3INSIDE', 0.0)", "('CDLKICKINGBYLENGTH', -100.0)"],
#  ["('CDL3INSIDE', 100.0)", "('CDLHIKKAKEMOD', 100.0)"],
#  ["('CDL3INSIDE', -100.0)", "('CDLDRAGONFLYDOJI', 100.0)"],
#  ["('CDL3INSIDE', -100.0)", "('CDLHANGINGMAN', -100.0)"],
#  ["('CDL3INSIDE', -100.0)", "('CDLHIKKAKEMOD', -200.0)"],
#  ["('CDL3INSIDE', -100.0)", "('CDLMATCHINGLOW', 100.0)"],
#  ["('CDL3INSIDE', -100.0)", "('CDLTAKURI', 100.0)"],
#  ["('CDL3LINESTRIKE', 0.0)", "('CDLKICKING', 100.0)"],
# ...

# %%
signals = []
values = []

for i in range(len(z)):
    sig = []
    val = []
    for j in range(len(z[i])):
        cage = z[i][j].split(",")
        print(cage)
        sig.append(cage[0])
        val.append(cage[1])
        
    signals.append(sig)
    values.append(val)
# Out:
# ["('CDL2CROWS'", ' 0.0)']
# ["('CDLKICKING'", ' 100.0)']
# ["('CDL2CROWS'", ' 0.0)']
# ["('CDLKICKINGBYLENGTH'", ' -100.0)']
# ["('CDL2CROWS'", ' -100.0)']
# ["('CDLGRAVESTONEDOJI'", ' 100.0)']
# ["('CDL2CROWS'", ' -100.0)']
# ["('CDLTAKURI'", ' 100.0)']
# ["('CDL2CROWS'", ' -100.0)']
# ["('CDLTRISTAR'", ' -100.0)']
# ["('CDL3BLACKCROWS'", ' 0.0)']
# ["('CDLKICKING'", ' 100.0)']
# ["('CDL3BLACKCROWS'", ' 0.0)']
# ["('CDLKICKINGBYLENGTH'", ' -100.0)']
# ["('CDL3INSIDE'", ' 0.0)']
# ["('CDLKICKING'", ' 100.0)']
# ["('CDL3INSIDE'", ' 0.0)']
# ["('CDLKICKINGBYLENGTH'", ' -100.0)']
# ["('CDL3INSIDE'", ' 100.0)']
# ["('CDLHIKKAKEMOD'", ' 100.0)']
# ["('CDL3INSIDE'", ' -100.0)']
# ["('CDLDRAGONFLYDOJI'", ' 100.0)']
# ["('CDL3INSIDE'", ' -100.0)']
# ["('CDLHANGINGMAN'", ' -100.0)']
# ["('CDL3INSIDE'", ' -100.0)']
# ["('CDLHIKKAKEMOD'", ' -200.0)']
# ["('CDL3INSIDE'", ' -100.0)']
# ["('CDLMATCHINGLOW'", ' 100.0)']
# ["('CDL3INSIDE'", ' -100.0)']
# ["('CDLTAKURI'", ' 100.0)']
# ...

# %%
for i in range(len(signals)):
    signals[i][0] = signals[i][0].strip("('")
    signals[i][1] = signals[i][1].strip("('")

# %%
signals
# Out:
# [['CDL2CROWS', 'CDLKICKING'],
#  ['CDL2CROWS', 'CDLKICKINGBYLENGTH'],
#  ['CDL2CROWS', 'CDLGRAVESTONEDOJI'],
#  ['CDL2CROWS', 'CDLTAKURI'],
#  ['CDL2CROWS', 'CDLTRISTAR'],
#  ['CDL3BLACKCROWS', 'CDLKICKING'],
#  ['CDL3BLACKCROWS', 'CDLKICKINGBYLENGTH'],
#  ['CDL3INSIDE', 'CDLKICKING'],
#  ['CDL3INSIDE', 'CDLKICKINGBYLENGTH'],
#  ['CDL3INSIDE', 'CDLHIKKAKEMOD'],
#  ['CDL3INSIDE', 'CDLDRAGONFLYDOJI'],
#  ['CDL3INSIDE', 'CDLHANGINGMAN'],
#  ['CDL3INSIDE', 'CDLHIKKAKEMOD'],
#  ['CDL3INSIDE', 'CDLMATCHINGLOW'],
#  ['CDL3INSIDE', 'CDLTAKURI'],
#  ['CDL3LINESTRIKE', 'CDLKICKING'],
#  ['CDL3LINESTRIKE', 'CDLKICKINGBYLENGTH'],
#  ['CDL3LINESTRIKE', 'CDLDOJI'],
#  ['CDL3LINESTRIKE', 'CDLDRAGONFLYDOJI'],
#  ['CDL3LINESTRIKE', 'CDLLONGLEGGEDDOJI'],
#  ['CDL3LINESTRIKE', 'CDLSHORTLINE'],
#  ['CDL3LINESTRIKE', 'CDLTAKURI'],
#  ['CDL3LINESTRIKE', 'CDLDARKCLOUDCOVER'],
#  ['CDL3LINESTRIKE', 'CDLDRAGONFLYDOJI'],
#  ['CDL3LINESTRIKE', 'CDLHAMMER'],
#  ['CDL3LINESTRIKE', 'CDLHANGINGMAN'],
# ...

# %%
for i in range(len(values)):
    values[i][0] = float(values[i][0].strip(" )"))
    values[i][1] = float(values[i][1].strip(" )"))

# %%
values
# Out:
# [[0.0, 100.0],
#  [0.0, -100.0],
#  [-100.0, 100.0],
#  [-100.0, 100.0],
#  [-100.0, -100.0],
#  [0.0, 100.0],
#  [0.0, -100.0],
#  [0.0, 100.0],
#  [0.0, -100.0],
#  [100.0, 100.0],
#  [-100.0, 100.0],
#  [-100.0, -100.0],
#  [-100.0, -200.0],
#  [-100.0, 100.0],
#  [-100.0, 100.0],
#  [0.0, 100.0],
#  [0.0, -100.0],
#  [-100.0, 100.0],
#  [-100.0, 100.0],
#  [-100.0, 100.0],
#  [-100.0, 100.0],
#  [-100.0, 100.0],
#  [100.0, -100.0],
#  [100.0, 100.0],
#  [100.0, 100.0],
#  [100.0, -100.0],
#  [100.0, 100.0],
#  [100.0, -200.0],
#  [100.0, 100.0],
#  [100.0, 100.0],
#  [0.0, 100.0],
#  [0.0, -100.0],
#  [100.0, -100.0],
#  [100.0, -100.0],
#  [100.0, -100.0],
#  [0.0, 100.0],
#  [0.0, -100.0],
#  [0.0, 100.0],
#  [0.0, -100.0],
#  [0.0, 100.0],
#  [0.0, -100.0],
#  [-100.0, 100.0],
#  [-100.0, 0.0],
#  [-100.0, -100.0],
#  [-100.0, -100.0],
#  [-100.0, -100.0],
#  [0.0, 100.0],
#  [0.0, -100.0],
#  [-100.0, -100.0],
#  [100.0, 100.0],
#  [100.0, -200.0],
#  [100.0, -200.0],
# ...

# %%
weights = [float(odf.loc[c, ['weights']]) for c in odf.index]

# %%
len(weights)
# Out:
# 249

# %%
from itertools import chain
needToGet = set(list(chain.from_iterable(signals)))

# %%
needToGet
# Out:
# {'CDL2CROWS',
#  'CDL3BLACKCROWS',
#  'CDL3INSIDE',
#  'CDL3LINESTRIKE',
#  'CDL3OUTSIDE',
#  'CDL3STARSINSOUTH',
#  'CDL3WHITESOLDIERS',
#  'CDLABANDONEDBABY',
#  'CDLADVANCEBLOCK',
#  'CDLBELTHOLD',
#  'CDLBREAKAWAY',
#  'CDLCLOSINGMARUBOZU',
#  'CDLCONCEALBABYSWALL',
#  'CDLCOUNTERATTACK',
#  'CDLDARKCLOUDCOVER',
#  'CDLDOJI',
#  'CDLDOJISTAR',
#  'CDLDRAGONFLYDOJI',
#  'CDLENGULFING',
#  'CDLEVENINGDOJISTAR',
#  'CDLEVENINGSTAR',
#  'CDLGAPSIDESIDEWHITE',
#  'CDLGRAVESTONEDOJI',
#  'CDLHAMMER',
#  'CDLHANGINGMAN',
#  'CDLHARAMI',
#  'CDLHARAMICROSS',
#  'CDLHIGHWAVE',
#  'CDLHIKKAKE',
#  'CDLHIKKAKEMOD',
#  'CDLHOMINGPIGEON',
#  'CDLIDENTICAL3CROWS',
#  'CDLINNECK',
#  'CDLINVERTEDHAMMER',
#  'CDLKICKING',
#  'CDLKICKINGBYLENGTH',
#  'CDLLADDERBOTTOM',
#  'CDLLONGLEGGEDDOJI',
#  'CDLLONGLINE',
#  'CDLMARUBOZU',
#  'CDLMATCHINGLOW',
#  'CDLMATHOLD',
#  'CDLMORNINGDOJISTAR',
#  'CDLMORNINGSTAR',
#  'CDLONNECK',
#  'CDLPIERCING',
#  'CDLRICKSHAWMAN',
#  'CDLRISEFALL3METHODS',
# ...

# %%
fixed = [list(zip(signals[c], values[c])) for c in range(len(signals))]

# %%
fixed
# Out:
# [[('CDL2CROWS', 0.0), ('CDLKICKING', 100.0)],
#  [('CDL2CROWS', 0.0), ('CDLKICKINGBYLENGTH', -100.0)],
#  [('CDL2CROWS', -100.0), ('CDLGRAVESTONEDOJI', 100.0)],
#  [('CDL2CROWS', -100.0), ('CDLTAKURI', 100.0)],
#  [('CDL2CROWS', -100.0), ('CDLTRISTAR', -100.0)],
#  [('CDL3BLACKCROWS', 0.0), ('CDLKICKING', 100.0)],
#  [('CDL3BLACKCROWS', 0.0), ('CDLKICKINGBYLENGTH', -100.0)],
#  [('CDL3INSIDE', 0.0), ('CDLKICKING', 100.0)],
#  [('CDL3INSIDE', 0.0), ('CDLKICKINGBYLENGTH', -100.0)],
#  [('CDL3INSIDE', 100.0), ('CDLHIKKAKEMOD', 100.0)],
#  [('CDL3INSIDE', -100.0), ('CDLDRAGONFLYDOJI', 100.0)],
#  [('CDL3INSIDE', -100.0), ('CDLHANGINGMAN', -100.0)],
#  [('CDL3INSIDE', -100.0), ('CDLHIKKAKEMOD', -200.0)],
#  [('CDL3INSIDE', -100.0), ('CDLMATCHINGLOW', 100.0)],
#  [('CDL3INSIDE', -100.0), ('CDLTAKURI', 100.0)],
#  [('CDL3LINESTRIKE', 0.0), ('CDLKICKING', 100.0)],
#  [('CDL3LINESTRIKE', 0.0), ('CDLKICKINGBYLENGTH', -100.0)],
#  [('CDL3LINESTRIKE', -100.0), ('CDLDOJI', 100.0)],
# ...

# %%
len(needToGet)
# Out:
# 61

# %%
for i in needToGet:
    e = f'''
'{i}': TA_factors.{i}(),'''.strip()
    print(e)
# Out:
# 'CDLTASUKIGAP': TA_factors.CDLTASUKIGAP(),
# 'CDLEVENINGSTAR': TA_factors.CDLEVENINGSTAR(),
# 'CDLLADDERBOTTOM': TA_factors.CDLLADDERBOTTOM(),
# 'CDLUPSIDEGAP2CROWS': TA_factors.CDLUPSIDEGAP2CROWS(),
# 'CDLHANGINGMAN': TA_factors.CDLHANGINGMAN(),
# 'CDLIDENTICAL3CROWS': TA_factors.CDLIDENTICAL3CROWS(),
# 'CDLGRAVESTONEDOJI': TA_factors.CDLGRAVESTONEDOJI(),
# 'CDLMATCHINGLOW': TA_factors.CDLMATCHINGLOW(),
# 'CDL3WHITESOLDIERS': TA_factors.CDL3WHITESOLDIERS(),
# 'CDLSHOOTINGSTAR': TA_factors.CDLSHOOTINGSTAR(),
# 'CDLCONCEALBABYSWALL': TA_factors.CDLCONCEALBABYSWALL(),
# 'CDLCOUNTERATTACK': TA_factors.CDLCOUNTERATTACK(),
# 'CDLLONGLEGGEDDOJI': TA_factors.CDLLONGLEGGEDDOJI(),
# 'CDLTAKURI': TA_factors.CDLTAKURI(),
# 'CDL3OUTSIDE': TA_factors.CDL3OUTSIDE(),
# 'CDLSTALLEDPATTERN': TA_factors.CDLSTALLEDPATTERN(),
# 'CDLUNIQUE3RIVER': TA_factors.CDLUNIQUE3RIVER(),
# 'CDLADVANCEBLOCK': TA_factors.CDLADVANCEBLOCK(),
# 'CDLKICKING': TA_factors.CDLKICKING(),
# ...
